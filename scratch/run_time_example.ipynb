# %%
from pysocialwatcher import watcherAPI

from mysocialwatcher.collector.utils import estimate_run_time

# %%
pwd
# Out:
# '/Users/caseybreen/workspace/mySocialWatcher/scratch'

# %%
estimate_run_time(specs_dir = "docker/collectors/badger/dgg_national_ins/specs/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 estimate_run_time(specs_dir = "docker/collectors/badger/dgg_national_ins/specs/")
#       3 estimate_run_time(specs_dir = "docker/collectors/badger/dgg_national/specs/")
#
# File ~/workspace/mySocialWatcher/mysocialwatcher/collector/utils.py:105, in estimate_run_time(specs_dir, n_tokens, units, sleep_time)
#     103 def estimate_run_time(specs_dir, n_tokens=1, units='d', sleep_time=11):
#     104     runtime = 0
# --> 105     specs_list = os.listdir(specs_dir)
#     106     for specs_file in specs_list:
#     107         with open(os.path.join(specs_dir, specs_file)) as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'docker/collectors/badger/dgg_national_ins/specs/'

# %%
estimate_run_time(specs_dir = "docker/collectors/badger/dgg_national/specs/")
